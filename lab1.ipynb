# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ##### 读取相关数据，将数据集随机分为80%训练集，20%测试集

# %%
rating = pd.read_csv("/Users/JiaoFusen/Desktop/ml-latest-small/ratings.csv")
movie = pd.read_csv("/Users/JiaoFusen/Desktop/ml-latest-small/movies.csv")
ratings = pd.merge(rating, movie, on="movieId")
ratings_train, ratings_test = train_test_split(ratings, train_size=0.8)
ratings_train
# Out:
# /Users/JiaoFusen/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>userId</th>
#       <th>movieId</th>
#       <th>rating</th>
#       <th>timestamp</th>
#       <th>title</th>
#       <th>genres</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>20617</th>
#       <td>159</td>
#       <td>2000</td>
#       <td>4.0</td>
#       <td>1183519353</td>
#       <td>Lethal Weapon (1987)</td>
#       <td>Action|Comedy|Crime|Drama</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ###### 输出训练集中用户观看电影数量

# %%
ratings_train['userId'].value_counts()
# Out:
# 547    1911
# 564    1482
# 624    1391
# 15     1357
# 73     1269
# 452    1105
# 468    1046
# 380     861
# 311     830
# 30      803
# 294     754
# 580     737
# 213     730
# 509     713
# 212     693
# 472     662
# 388     641
# 23      580
# 518     566
# 457     560
# 232     543
# 102     543
# 262     542
# 461     532
# 475     521
# 654     512
# 119     509
# 358     502
# 306     499
# 529     475
#        ...
# 604      17
# 280      17
# 331      17
# 448      16
# 1        16
# 638      16
# 513      16
# 347      16
# 438      16
# 435      16
# 296      16
# 209      16
# 485      16
# 167      16
# 356      15
# 14       15
# 109      15
# 45       15
# 319      15
# 469      15
# 325      15
# 668      15
# 444      15
# 540      14
# 335      14
# 498      14
# 368      14
# 651      14
# 399      13
# 403      11
# Name: userId, Length: 671, dtype: int64

# %% [markdown]
# ###### 查看电影被观看的次数

# %%
ratings_train['title'].value_counts()
# Out:
# Forrest Gump (1994)                                                                   265
# Shawshank Redemption, The (1994)                                                      260
# Pulp Fiction (1994)                                                                   259
# Silence of the Lambs, The (1991)                                                      246
# Star Wars: Episode IV - A New Hope (1977)                                             223
# Jurassic Park (1993)                                                                  223
# Matrix, The (1999)                                                                    213
# Schindler's List (1993)                                                               202
# Toy Story (1995)                                                                      201
# Terminator 2: Judgment Day (1991)                                                     196
# ...

# %% [markdown]
# ###### 查看评分数据的平均值等数据

# %%
ratings_train["rating"].describe()
# Out:
# count    80003.000000
# mean         3.545005
# std          1.059882
# min          0.500000
# 25%          3.000000
# 50%          4.000000
# 75%          4.000000
# max          5.000000
# Name: rating, dtype: float64

# %% [markdown]
# ###### 查看每一部电影评分的平均值状况

# %%
ratings_train.groupby('movieId')['rating'].mean()
# Out:
# movieId
# 1         3.922886
# 2         3.398810
# 3         3.169811
# 4         2.272727
# 5         3.337209
# 6         3.934066
# 7         3.292683
# 8         3.800000
# 9         3.250000
# 10        3.456989
# 11        3.649254
# 12        2.906250
# 13        3.833333
# 14        3.318182
# 15        2.250000
# 16        3.864865
# 17        3.959016
# 18        3.363636
# 19        2.626506
# 20        2.500000
# 21        3.628788
# 22        3.300000
# 23        3.031250
# 24        3.180000
# 25        3.683544
# 26        3.875000
# 27        3.250000
# 28        4.038462
# 29        3.965517
# 30        4.055556
#             ...
# 156607    1.250000
# 156609    3.750000
# 157200    1.500000
# 157296    4.000000
# 157407    1.500000
# 157667    1.500000
# 158238    3.750000
# 158314    4.500000
# 158528    3.500000
# 158956    4.000000
# 159093    3.000000
# 159462    3.000000
# 159755    1.000000
# 159858    3.750000
# 160080    1.000000
# 160271    2.500000
# ...

# %% [markdown]
# #### 对于experts的几个假设
# 1. 首先电影观看数量大于200(实际测试集中满足条件很少，实际使用时候选取top50观影人）
# 2. 对于好的电影评价应该也是好的，差的电影评价的评价也是差的

# %%
def getExperts(x):
    experts = x['userId'].value_counts()
    experts = experts.head(50)
    return experts

getExperts(ratings_train)
# Out:
# 547    1911
# 564    1482
# 624    1391
# 15     1357
# 73     1269
# 452    1105
# 468    1046
# 380     861
# 311     830
# 30      803
# 294     754
# 580     737
# 213     730
# 509     713
# 212     693
# 472     662
# 388     641
# 23      580
# 518     566
# 457     560
# 232     543
# 102     543
# 262     542
# 461     532
# 475     521
# 654     512
# 119     509
# 358     502
# 306     499
# 529     475
# 575     454
# 353     433
# 56      422
# 105     415
# 664     412
# 596     410
# 48      402
# 195     392
# 165     382
# 384     381
# 463     381
# 587     370
# 481     366
# 607     351
# 605     349
# 199     336
# 150     336
# 242     334
# 19      333
# 268     330
# Name: userId, dtype: int64
